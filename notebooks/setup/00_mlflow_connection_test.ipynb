# %%
import mlflow

TRACKING_URI = "http://ec2-54-88-191-111.compute-1.amazonaws.com:5000/"
mlflow.set_tracking_uri(TRACKING_URI)

with mlflow.start_run(run_name="mlflow_connection_test"):
    mlflow.log_param("test_param", 15)
    mlflow.log_metric("test_metric", 0.89)

print("Experiment logged successfully!")
# Out:
# 🏃 View run mlflow_connection_test at: http://ec2-54-88-191-111.compute-1.amazonaws.com:5000/#/experiments/0/runs/707b22a137df4449826daefbd608226a
# 🧪 View experiment at: http://ec2-54-88-191-111.compute-1.amazonaws.com:5000/#/experiments/0
# Experiment logged successfully!

# %% [markdown]
# ![MLflow Setup](../../images/mlflow_setup/setup2.png)
# ![MLflow Setup](../../images/mlflow_setup/setup1.png)
